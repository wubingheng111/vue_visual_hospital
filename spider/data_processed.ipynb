# %%
import pandas as pd

file_path = r'E:\daping\daping\hospital_sum'

excel_file = [f for f in file_path if f.endswith('.xls') or f.endswith('.xlsx')]



print(excel_file)

all_Data = pd.DataFrame()

for f in excel_file:
    data = pd.read_excel(f)
    print(data)
    all_Data = all_Data.append(data, ignore_index=True)

# %%
# 统计每个省份三甲医院数量

df_1 = pd.read_excel(r'E:\daping\daping\hospital_sum\安徽省医院数据汇总.xls')

# 统计每个省份三甲医院数量

df_1_hospitals = df_1["医院等级"].value_counts()
df_1_san_hospital = df_1[df_1["医院等级"] == "三级甲等"]
print("安徽省三甲医院数量为：", df_1_san_hospital.shape[0])
df_1_hospitals_guoying = df_1[df_1["经营方式"] == "国营"]
df_1_hospitals_guoying_san = df_1[df_1["经营方式"] != "国营"]
print("安徽省国盈三甲医院数量为：", df_1_hospitals_guoying_san.shape[0])
print("安徽省非国盈三甲医院数量为：", df_1_hospitals_guoying.shape[0])


df_2 = pd.read_excel(r'E:\daping\daping\hospital_sum\北京市医院数据汇总.xls')

df_2_hospitals = df_2["医院等级"].value_counts()
df_2_san_hospital = df_2[df_2["医院等级"] == "三级甲等"]
print("北京市三甲医院数量为：", df_2_san_hospital.shape[0])
df_2_hospitals_guoying = df_2[df_2["经营方式"] == "国营"]
df_2_hospitals_guoying_san = df_2[df_2["经营方式"] != "国营"]
print("北京市国盈三甲医院数量为：", df_2_hospitals_guoying_san.shape[0])
print("北京市非国盈三甲医院数量为：", df_2_hospitals_guoying.shape[0])


df_3 = pd.read_excel(r'E:\daping\daping\hospital_sum\福建省医院数据汇总.xls')

df_3_hospitals = df_3["医院等级"].value_counts()
df_3_san_hospital = df_3[df_3["医院等级"] == "三级甲等"]
print("福建省三甲医院数量为：", df_3_san_hospital.shape[0])
df_3_hospitals_guoying = df_3[df_3["经营方式"] == "国营"]
df_3_hospitals_guoying_san = df_3[df_3["经营方式"] != "国营"]
print("福建省国盈三甲医院数量为：", df_3_hospitals_guoying_san.shape[0])
print("福建省非国盈三甲医院数量为：", df_3_hospitals_guoying.shape[0])


df_4 = pd.read_excel(r'E:\daping\daping\hospital_sum\甘肃省医院数据汇总.xls')

df_4_hospitals = df_4["医院等级"].value_counts()
df_4_san_hospital = df_4[df_4["医院等级"] == "三级甲等"]
print("甘肃省三甲医院数量为：", df_4_san_hospital.shape[0])
df_4_hospitals_guoying = df_4[df_4["经营方式"] == "国营"]

df_4_hospitals_guoying_san = df_4[df_4["经营方式"] != "国营"]
print("甘肃省国盈三甲医院数量为：", df_4_hospitals_guoying_san.shape[0])
print("甘肃省非国盈三甲医院数量为：", df_4_hospitals_guoying.shape[0])


df_5 = pd.read_excel(r'E:\daping\daping\hospital_sum\广东省医院数据汇总.xls')

df_5_hospitals = df_5["医院等级"].value_counts()
df_5_san_hospital = df_5[df_5["医院等级"] == "三级甲等"]
print("广东省三甲医院数量为：", df_5_san_hospital.shape[0])
df_5_hospitals_guoying = df_5[df_5["经营方式"] == "国营"]
df_5_hospitals_guoying_san = df_5[df_5["经营方式"] != "国营"]
print("广东省国盈三甲医院数量为：", df_5_hospitals_guoying_san.shape[0])
print("广东省非国盈三甲医院数量为：", df_5_hospitals_guoying.shape[0])


df_6 = pd.read_excel(r'E:\daping\daping\hospital_sum\广西壮族自治区医院数据汇总.xls')

df_6_hospitals = df_6["医院等级"].value_counts()
df_6_san_hospital = df_6[df_6["医院等级"] == "三级甲等"]
print("广西壮族自治区三甲医院数量为：", df_6_san_hospital.shape[0])
df_6_hospitals_guoying = df_6[df_6["经营方式"] == "国营"]

df_6_hospitals_guoying_san = df_6[df_6["经营方式"] != "国营"]
print("广西壮族自治区国盈三甲医院数量为：", df_6_hospitals_guoying_san.shape[0])
print("广西壮族自治区非国盈三甲医院数量为：", df_6_hospitals_guoying.shape[0])


df_7 = pd.read_excel(r'E:\daping\daping\hospital_sum\贵州省医院数据汇总.xls')

df_7_hospitals = df_7["医院等级"].value_counts()
df_7_san_hospital = df_7[df_7["医院等级"] == "三级甲等"]
print("贵州省三甲医院数量为：", df_7_san_hospital.shape[0])
df_7_hospitals_guoying = df_7[df_7["经营方式"] == "国营"]

df_7_hospitals_guoying_san = df_7[df_7["经营方式"] != "国营"]
print("贵州省国盈三甲医院数量为：", df_7_hospitals_guoying_san.shape[0])
print("贵州省非国盈三甲医院数量为：", df_7_hospitals_guoying.shape[0])


df_8 = pd.read_excel(r'E:\daping\daping\hospital_sum\海南省医院数据汇总.xls')

df_8_hospitals = df_8["医院等级"].value_counts()
df_8_san_hospital = df_8[df_8["医院等级"] == "三级甲等"]
print("海南省三甲医院数量为：", df_8_san_hospital.shape[0])
df_8_hospitals_guoying = df_8[df_8["经营方式"] == "国营"]

df_8_hospitals_guoying_san = df_8[df_8["经营方式"] != "国营"]
print("海南省国盈三甲医院数量为：", df_8_hospitals_guoying_san.shape[0])
print("海南省非国盈三甲医院数量为：", df_8_hospitals_guoying.shape[0])


df_9 = pd.read_excel(r'E:\daping\daping\hospital_sum\河北省医院数据汇总.xls')

df_9_hospitals = df_9["医院等级"].value_counts()
df_9_san_hospital = df_9[df_9["医院等级"] == "三级甲等"]
print("河北省三甲医院数量为：", df_9_san_hospital.shape[0])
df_9_hospitals_guoying = df_9[df_9["经营方式"] == "国营"]

df_9_hospitals_guoying_san = df_9[df_9["经营方式"] != "国营"]
print("河北省国盈三甲医院数量为：", df_9_hospitals_guoying_san.shape[0])

print("河北省非国盈三甲医院数量为：", df_9_hospitals_guoying.shape[0])


df_10 = pd.read_excel(r'E:\daping\daping\hospital_sum\河南省医院数据汇总.xls')

df_10_hospitals = df_10["医院等级"].value_counts()

df_10_san_hospital = df_10[df_10["医院等级"] == "三级甲等"]
print("河南省三甲医院数量为：", df_10_san_hospital.shape[0])

df_10_hospitals_guoying = df_10[df_10["经营方式"] == "国营"]

df_10_hospitals_guoying_san = df_10[df_10["经营方式"] != "国营"]
print("河南省国盈三甲医院数量为：", df_10_hospitals_guoying_san.shape[0])

print("河南省非国盈三甲医院数量为：", df_10_hospitals_guoying.shape[0])


df_11 = pd.read_excel(r'E:\daping\daping\hospital_sum\黑龙江省医院数据汇总.xls')

df_11_hospitals = df_11["医院等级"].value_counts()

df_11_san_hospital = df_11[df_11["医院等级"] == "三级甲等"]

print("黑龙江省三甲医院数量为：", df_11_san_hospital.shape[0])

df_11_hospitals_guoying = df_11[df_11["经营方式"] == "国营"]

df_11_hospitals_guoying_san = df_11[df_11["经营方式"] != "国营"]

print("黑龙江省国盈三甲医院数量为：", df_11_hospitals_guoying_san.shape[0])

print("黑龙江省非国盈三甲医院数量为：", df_11_hospitals_guoying.shape[0])


df_12 = pd.read_excel(r'E:\daping\daping\hospital_sum\湖北省医院数据汇总.xls')

df_12_hospitals = df_12["医院等级"].value_counts()

df_12_san_hospital = df_12[df_12["医院等级"] == "三级甲等"]

print("湖北省三甲医院数量为：", df_12_san_hospital.shape[0])

df_12_hospitals_guoying = df_12[df_12["经营方式"] == "国营"]

df_12_hospitals_guoying_san = df_12[df_12["经营方式"] != "国营"]

print("湖北省国盈三甲医院数量为：", df_12_hospitals_guoying_san.shape[0])


print("湖北省非国盈三甲医院数量为：", df_12_hospitals_guoying.shape[0])


df_13 = pd.read_excel(r'E:\daping\daping\hospital_sum\湖南省医院数据汇总.xls')

df_13_hospitals = df_13["医院等级"].value_counts()

df_13_san_hospital = df_13[df_13["医院等级"] == "三级甲等"]

print("湖南省三甲医院数量为：", df_13_san_hospital.shape[0])

df_13_hospitals_guoying = df_13[df_13["经营方式"] == "国营"]

df_13_hospitals_guoying_san = df_13[df_13["经营方式"] != "国营"]

print("湖南省国盈三甲医院数量为：", df_13_hospitals_guoying_san.shape[0])

print("湖南省非国盈三甲医院数量为：", df_13_hospitals_guoying.shape[0])


df_14 = pd.read_excel(r'E:\daping\daping\hospital_sum\吉林省医院数据汇总.xls')


df_14_hospitals = df_14["医院等级"].value_counts()

df_14_san_hospital = df_14[df_14["医院等级"] == "三级甲等"]

print("吉林省三甲医院数量为：", df_14_san_hospital.shape[0])

df_14_hospitals_guoying = df_14[df_14["经营方式"] == "国营"]

df_14_hospitals_guoying_san = df_14[df_14["经营方式"] != "国营"]

print("吉林省国盈三甲医院数量为：", df_14_hospitals_guoying_san.shape[0])


print("吉林省非国盈三甲医院数量为：", df_14_hospitals_guoying.shape[0])


df_15 = pd.read_excel(r'E:\daping\daping\hospital_sum\江苏省医院数据汇总.xls')


df_15_hospitals = df_15["医院等级"].value_counts()

df_15_san_hospital = df_15[df_15["医院等级"] == "三级甲等"]

print("江苏省三甲医院数量为：", df_15_san_hospital.shape[0])

df_15_hospitals_guoying = df_15[df_15["经营方式"] == "国营"]

df_15_hospitals_guoying_san = df_15[df_15["经营方式"] != "国营"]

print("江苏省国盈三甲医院数量为：", df_15_hospitals_guoying_san.shape[0])

print("江苏省非国盈三甲医院数量为：", df_15_hospitals_guoying.shape[0])


df_16 = pd.read_excel(r'E:\daping\daping\hospital_sum\江西省医院数据汇总.xls')


df_16_hospitals = df_16["医院等级"].value_counts()

df_16_san_hospital = df_16[df_16["医院等级"] == "三级甲等"]

print("江西省三甲医院数量为：", df_16_san_hospital.shape[0])

df_16_hospitals_guoying = df_16[df_16["经营方式"] == "国营"]

df_16_hospitals_guoying_san = df_16[df_16["经营方式"] != "国营"]


print("江西省国盈三甲医院数量为：", df_16_hospitals_guoying_san.shape[0])


print("江西省非国盈三甲医院数量为：", df_16_hospitals_guoying.shape[0])


df_17 = pd.read_excel(r'E:\daping\daping\hospital_sum\辽宁省医院数据汇总.xls')  


df_17_hospitals = df_17["医院等级"].value_counts()

df_17_san_hospital = df_17[df_17["医院等级"] == "三级甲等"]

print("辽宁省三甲医院数量为：", df_17_san_hospital.shape[0])


df_17_hospitals_guoying = df_17[df_17["经营方式"] == "国营"]

df_17_hospitals_guoying_san = df_17[df_17["经营方式"] != "国营"]

print("辽宁省国盈三甲医院数量为：", df_17_hospitals_guoying_san.shape[0])

print("辽宁省非国盈三甲医院数量为：", df_17_hospitals_guoying.shape[0])


df_18 = pd.read_excel(r'E:\daping\daping\hospital_sum\内蒙古自治区医院数据汇总.xls')


df_18_hospitals = df_18["医院等级"].value_counts()

df_18_san_hospital = df_18[df_18["医院等级"] == "三级甲等"]

print("内蒙古自治区三甲医院数量为：", df_18_san_hospital.shape[0])

df_18_hospitals_guoying = df_18[df_18["经营方式"] == "国营"]

df_18_hospitals_guoying_san = df_18[df_18["经营方式"] != "国营"]

print("内蒙古自治区国盈三甲医院数量为：", df_18_hospitals_guoying_san.shape[0])

print("内蒙古自治区非国盈三甲医院数量为：", df_18_hospitals_guoying.shape[0])


df_19 = pd.read_excel(r'E:\daping\daping\hospital_sum\宁夏回族自治区医院数据汇总.xls')


df_19_hospitals = df_19["医院等级"].value_counts()

df_19_san_hospital = df_19[df_19["医院等级"] == "三级甲等"]

print("宁夏回族自治区三甲医院数量为：", df_19_san_hospital.shape[0])

df_19_hospitals_guoying = df_19[df_19["经营方式"] == "国营"]

df_19_hospitals_guoying_san = df_19[df_19["经营方式"] != "国营"]

print("宁夏回族自治区国盈三甲医院数量为：", df_19_hospitals_guoying_san.shape[0])


print("宁夏回族自治区非国盈三甲医院数量为：", df_19_hospitals_guoying.shape[0])


df_20 = pd.read_excel(r'E:\daping\daping\hospital_sum\青海省医院数据汇总.xls')


df_20_hospitals = df_20["医院等级"].value_counts()

df_20_san_hospital = df_20[df_20["医院等级"] == "三级甲等"]

print("青海省三甲医院数量为：", df_20_san_hospital.shape[0])

df_20_hospitals_guoying = df_20[df_20["经营方式"] == "国营"]

df_20_hospitals_guoying_san = df_20[df_20["经营方式"] != "国营"]

print("青海省国盈三甲医院数量为：", df_20_hospitals_guoying_san.shape[0])

print("青海省非国盈三甲医院数量为：", df_20_hospitals_guoying.shape[0])


df_21 = pd.read_excel(r'E:\daping\daping\hospital_sum\山东省医院数据汇总.xls')


df_21_hospitals = df_21["医院等级"].value_counts()

df_21_san_hospital = df_21[df_21["医院等级"] == "三级甲等"]

print("山东省三甲医院数量为：", df_21_san_hospital.shape[0])

df_21_hospitals_guoying = df_21[df_21["经营方式"] == "国营"]

df_21_hospitals_guoying_san = df_21[df_21["经营方式"] != "国营"]

print("山东省国盈三甲医院数量为：", df_21_hospitals_guoying_san.shape[0])

print("山东省非国盈三甲医院数量为：", df_21_hospitals_guoying.shape[0])


df_22 = pd.read_excel(r'E:\daping\daping\hospital_sum\山西省医院数据汇总.xls')


df_22_hospitals = df_22["医院等级"].value_counts()

df_22_san_hospital = df_22[df_22["医院等级"] == "三级甲等"]

print("山西省三甲医院数量为：", df_22_san_hospital.shape[0])


df_22_hospitals_guoying = df_22[df_22["经营方式"] == "国营"]

df_22_hospitals_guoying_san = df_22[df_22["经营方式"] != "国营"]

print("山西省国盈三甲医院数量为：", df_22_hospitals_guoying_san.shape[0])

print("山西省非国盈三甲医院数量为：", df_22_hospitals_guoying.shape[0])


df_23 = pd.read_excel(r'E:\daping\daping\hospital_sum\陕西省医院数据汇总.xls')


df_23_hospitals = df_23["医院等级"].value_counts()

df_23_san_hospital = df_23[df_23["医院等级"] == "三级甲等"]

print("陕西省三甲医院数量为：", df_23_san_hospital.shape[0])

df_23_hospitals_guoying = df_23[df_23["经营方式"] == "国营"]

df_23_hospitals_guoying_san = df_23[df_23["经营方式"] != "国营"]

print("陕西省国盈三甲医院数量为：", df_23_hospitals_guoying_san.shape[0])

print("陕西省非国盈三甲医院数量为：", df_23_hospitals_guoying.shape[0])


df_24 = pd.read_excel(r'E:\daping\daping\hospital_sum\上海市医院数据汇总.xls')


df_24_hospitals = df_24["医院等级"].value_counts()


df_24_san_hospital = df_24[df_24["医院等级"] == "三级甲等"]

print("上海市三甲医院数量为：", df_24_san_hospital.shape[0])

df_24_hospitals_guoying = df_24[df_24["经营方式"] == "国营"]

df_24_hospitals_guoying_san = df_24[df_24["经营方式"] != "国营"]

print("上海市国盈三甲医院数量为：", df_24_hospitals_guoying_san.shape[0])

print("上海市非国盈三甲医院数量为：", df_24_hospitals_guoying.shape[0])


df_25 = pd.read_excel(r'E:\daping\daping\hospital_sum\四川省医院数据汇总.xls')


df_25_hospitals = df_25["医院等级"].value_counts()

df_25_san_hospital = df_25[df_25["医院等级"] == "三级甲等"]

print("四川省三甲医院数量为：", df_25_san_hospital.shape[0])

df_25_hospitals_guoying = df_25[df_25["经营方式"] == "国营"]

df_25_hospitals_guoying_san = df_25[df_25["经营方式"] != "国营"]

print("四川省国盈三甲医院数量为：", df_25_hospitals_guoying_san.shape[0])

print("四川省非国盈三甲医院数量为：", df_25_hospitals_guoying.shape[0])


df_26 = pd.read_excel(r'E:\daping\daping\hospital_sum\天津市医院数据汇总.xls')


df_26_hospitals = df_26["医院等级"].value_counts()

df_26_san_hospital = df_26[df_26["医院等级"] == "三级甲等"]

print("天津市三甲医院数量为：", df_26_san_hospital.shape[0])

df_26_hospitals_guoying = df_26[df_26["经营方式"] == "国营"]

df_26_hospitals_guoying_san = df_26[df_26["经营方式"] != "国营"]

print("天津市国盈三甲医院数量为：", df_26_hospitals_guoying_san.shape[0])

print("天津市非国盈三甲医院数量为：", df_26_hospitals_guoying.shape[0])


df_27 = pd.read_excel(r'E:\daping\daping\hospital_sum\西藏自治区医院数据汇总.xls')


df_27_hospitals = df_27["医院等级"].value_counts()

df_27_san_hospital = df_27[df_27["医院等级"] == "三级甲等"]



print("西藏自治区三甲医院数量为：", df_27_san_hospital.shape[0])

df_27_hospitals_guoying = df_27[df_27["经营方式"] == "国营"]

df_27_hospitals_guoying_san = df_27[df_27["经营方式"] != "国营"]

print("西藏自治区国盈三甲医院数量为：", df_27_hospitals_guoying_san.shape[0])

print("西藏自治区非国盈三甲医院数量为：", df_27_hospitals_guoying.shape[0])


df_28 = pd.read_excel(r'E:\daping\daping\hospital_sum\新疆维吾尔自治区医院数据汇总.xls')


df_28_hospitals = df_28["医院等级"].value_counts()

df_28_san_hospital = df_28[df_28["医院等级"] == "三级甲等"]

print("新疆维吾尔自治区三甲医院数量为：", df_28_san_hospital.shape[0])


df_28_hospitals_guoying = df_28[df_28["经营方式"] == "国营"]

df_28_hospitals_guoying_san = df_28[df_28["经营方式"] != "国营"]

print("新疆维吾尔自治区国盈三甲医院数量为：", df_28_hospitals_guoying_san.shape[0])

print("新疆维吾尔自治区非国盈三甲医院数量为：", df_28_hospitals_guoying.shape[0])


df_29 = pd.read_excel(r'E:\daping\daping\hospital_sum\云南省医院数据汇总.xls')


df_29_hospitals = df_29["医院等级"].value_counts()

df_29_san_hospital = df_29[df_29["医院等级"] == "三级甲等"]

print("云南省三甲医院数量为：", df_29_san_hospital.shape[0])

df_29_hospitals_guoying = df_29[df_29["经营方式"] == "国营"]

df_29_hospitals_guoying_san = df_29[df_29["经营方式"] != "国营"]

print("云南省国盈三甲医院数量为：", df_29_hospitals_guoying_san.shape[0])

print("云南省非国盈三甲医院数量为：", df_29_hospitals_guoying.shape[0])


df_30 = pd.read_excel(r'E:\daping\daping\hospital_sum\浙江省医院数据汇总.xls')


df_30_hospitals = df_30["医院等级"].value_counts()

df_30_san_hospital = df_30[df_30["医院等级"] == "三级甲等"]

print("浙江省三甲医院数量为：", df_30_san_hospital.shape[0])

df_30_hospitals_guoying = df_30[df_30["经营方式"] == "国营"]

df_30_hospitals_guoying_san = df_30[df_30["经营方式"] != "国营"]

print("浙江省国盈三甲医院数量为：", df_30_hospitals_guoying_san.shape[0])

print("浙江省非国盈三甲医院数量为：", df_30_hospitals_guoying.shape[0])


df_31 = pd.read_excel(r'E:\daping\daping\hospital_sum\重庆市医院数据汇总.xls')


df_31_hospitals = df_31["医院等级"].value_counts()

df_31_san_hospital = df_31[df_31["医院等级"] == "三级甲等"]

print("重庆市三甲医院数量为：", df_31_san_hospital.shape[0])

df_31_hospitals_guoying = df_31[df_31["经营方式"] == "国营"]

df_31_hospitals_guoying_san = df_31[df_31["经营方式"] != "国营"]

print("重庆市国盈三甲医院数量为：", df_31_hospitals_guoying_san.shape[0])

print("重庆市非国盈三甲医院数量为：", df_31_hospitals_guoying.shape[0])


df_32 = pd.read_excel(r'E:\daping\daping\hospital_sum\安徽省医院数据汇总.xls')


df_32_hospitals = df_32["医院等级"].value_counts()

df_32_san_hospital = df_32[df_32["医院等级"] == "三级甲等"]

print("安徽省三甲医院数量为：", df_32_san_hospital.shape[0])

df_32_hospitals_guoying = df_32[df_32["经营方式"] == "国营"]

df_32_hospitals_guoying_san = df_32[df_32["经营方式"] != "国营"]


print("安徽省国盈三甲医院数量为：", df_32_hospitals_guoying_san.shape[0])

print("安徽省非国盈三甲医院数量为：", df_32_hospitals_guoying.shape[0])


df_33 = pd.read_excel(r'E:\daping\daping\hospital_sum\北京市医院数据汇总.xls')


df_33_hospitals = df_33["医院等级"].value_counts()

df_33_san_hospital = df_33[df_33["医院等级"] == "三级甲等"]

print("北京市三甲医院数量为：", df_33_san_hospital.shape[0])

df_33_hospitals_guoying = df_33[df_33["经营方式"] == "国营"]

df_33_hospitals_guoying_san = df_33[df_33["经营方式"] != "国营"]

print("北京市国盈三甲医院数量为：", df_33_hospitals_guoying_san.shape[0])

print("北京市非国盈三甲医院数量为：", df_33_hospitals_guoying.shape[0])


df_34 = pd.read_excel(r'E:\daping\daping\hospital_sum\福建省医院数据汇总.xls')


df_34_hospitals = df_34["医院等级"].value_counts()


df_34_san_hospital = df_34[df_34["医院等级"] == "三级甲等"]

print("福建省三甲医院数量为：", df_34_san_hospital.shape[0])


df_34_hospitals_guoying = df_34[df_34["经营方式"] == "国营"]

df_34_hospitals_guoying_san = df_34[df_34["经营方式"] != "国营"]

print("福建省国盈三甲医院数量为：", df_34_hospitals_guoying_san.shape[0])

print("福建省非国盈三甲医院数量为：", df_34_hospitals_guoying.shape[0])


df_35 = pd.read_excel(r'E:\daping\daping\hospital_sum\甘肃省医院数据汇总.xls')


df_35_hospitals = df_35["医院等级"].value_counts()


df_35_san_hospital = df_35[df_35["医院等级"] == "三级甲等"]

print("甘肃省三甲医院数量为：", df_35_san_hospital.shape[0])

df_35_hospitals_guoying = df_35[df_35["经营方式"] == "国营"]

df_35_hospitals_guoying_san = df_35[df_35["经营方式"] != "国营"]

print("甘肃省国盈三甲医院数量为：", df_35_hospitals_guoying_san.shape[0])


print("甘肃省非国盈三甲医院数量为：", df_35_hospitals_guoying.shape[0])


df_36 = pd.read_excel(r'E:\daping\daping\hospital_sum\广东省医院数据汇总.xls')


df_36_hospitals = df_36["医院等级"].value_counts()

df_36_san_hospital = df_36[df_36["医院等级"] == "三级甲等"]

print("广东省三甲医院数量为：", df_36_san_hospital.shape[0])

df_36_hospitals_guoying = df_36[df_36["经营方式"] == "国营"]

df_36_hospitals_guoying_san = df_36[df_36["经营方式"] != "国营"]

print("广东省国盈三甲医院数量为：", df_36_hospitals_guoying_san.shape[0])

print("广东省非国盈三甲医院数量为：", df_36_hospitals_guoying.shape[0])


df_37 = pd.read_excel(r'E:\daping\daping\hospital_sum\广西壮族自治区医院数据汇总.xls')


df_37_hospitals = df_37["医院等级"].value_counts()

df_37_san_hospital = df_37[df_37["医院等级"] == "三级甲等"]

print("广西壮族自治区三甲医院数量为：", df_37_san_hospital.shape[0])

df_37_hospitals_guoying = df_37[df_37["经营方式"] == "国营"]

df_37_hospitals_guoying_san = df_37[df_37["经营方式"] != "国营"]

print("广西壮族自治区国盈三甲医院数量为：", df_37_hospitals_guoying_san.shape[0])

print("广西壮族自治区非国盈三甲医院数量为：", df_37_hospitals_guoying.shape[0])


df_38 = pd.read_excel(r'E:\daping\daping\hospital_sum\贵州省医院数据汇总.xls')


df_38_hospitals = df_38["医院等级"].value_counts()

df_38_san_hospital = df_38[df_38["医院等级"] == "三级甲等"]

print("贵州省三甲医院数量为：", df_38_san_hospital.shape[0])

df_38_hospitals_guoying = df_38[df_38["经营方式"] == "国营"]

df_38_hospitals_guoying_san = df_38[df_38["经营方式"] != "国营"]

print("贵州省国盈三甲医院数量为：", df_38_hospitals_guoying_san.shape[0])

print("贵州省非国盈三甲医院数量为：", df_38_hospitals_guoying.shape[0])


df_39 = pd.read_excel(r'E:\daping\daping\hospital_sum\海南省医院数据汇总.xls')


df_39_hospitals = df_39["医院等级"].value_counts()

df_39_san_hospital = df_39[df_39["医院等级"] == "三级甲等"]

print("海南省三甲医院数量为：", df_39_san_hospital.shape[0])

df_39_hospitals_guoying = df_39[df_39["经营方式"] == "国营"]


df_39_hospitals_guoying_san = df_39[df_39["经营方式"] != "国营"]


print("海南省国盈三甲医院数量为：", df_39_hospitals_guoying_san.shape[0])


print("海南省非国盈三甲医院数量为：", df_39_hospitals_guoying.shape[0])


df_40 = pd.read_excel(r'E:\daping\daping\hospital_sum\河北省医院数据汇总.xls')


df_40_hospitals = df_40["医院等级"].value_counts()

df_40_san_hospital = df_40[df_40["医院等级"] == "三级甲等"]

print("河北省三甲医院数量为：", df_40_san_hospital.shape[0])


df_40_hospitals_guoying = df_40[df_40["经营方式"] == "国营"]

df_40_hospitals_guoying_san = df_40[df_40["经营方式"] != "国营"]


print("河北省国盈三甲医院数量为：", df_40_hospitals_guoying_san.shape[0])


print("河北省非国盈三甲医院数量为：", df_40_hospitals_guoying.shape[0])


df_41 = pd.read_excel(r'E:\daping\daping\hospital_sum\河南省医院数据汇总.xls')


df_41_hospitals = df_41["医院等级"].value_counts()


df_41_san_hospital = df_41[df_41["医院等级"] == "三级甲等"]

print("河南省三甲医院数量为：", df_41_san_hospital.shape[0])

df_41_hospitals_guoying = df_41[df_41["经营方式"] == "国营"]

df_41_hospitals_guoying_san = df_41[df_41["经营方式"] != "国营"]

print("河南省国盈三甲医院数量为：", df_41_hospitals_guoying_san.shape[0])

print("河南省非国盈三甲医院数量为：", df_41_hospitals_guoying.shape[0])


df_42 = pd.read_excel(r'E:\daping\daping\hospital_sum\黑龙江省医院数据汇总.xls')


df_42_hospitals = df_42["医院等级"].value_counts()


df_42_san_hospital = df_42[df_42["医院等级"] == "三级甲等"]

print("黑龙江省三甲医院数量为：", df_42_san_hospital.shape[0])

df_42_hospitals_guoying = df_42[df_42["经营方式"] == "国营"]


df_42_hospitals_guoying_san = df_42[df_42["经营方式"] != "国营"]


print("黑龙江省国盈三甲医院数量为：", df_42_hospitals_guoying_san.shape[0])

print("黑龙江省非国盈三甲医院数量为：", df_42_hospitals_guoying.shape[0])


df_43 = pd.read_excel(r'E:\daping\daping\hospital_sum\湖北省医院数据汇总.xls')


df_43_hospitals = df_43["医院等级"].value_counts()

df_43_san_hospital = df_43[df_43["医院等级"] == "三级甲等"]

print("湖北省三甲医院数量为：", df_43_san_hospital.shape[0])


df_43_hospitals_guoying = df_43[df_43["经营方式"] == "国营"]

df_43_hospitals_guoying_san = df_43[df_43["经营方式"] != "国营"]


print("湖北省国盈三甲医院数量为：", df_43_hospitals_guoying_san.shape[0])

print("湖北省非国盈三甲医院数量为：", df_43_hospitals_guoying.shape[0])


df_44 = pd.read_excel(r'E:\daping\daping\hospital_sum\湖南省医院数据汇总.xls')


df_44_hospitals = df_44["医院等级"].value_counts()

df_44_san_hospital = df_44[df_44["医院等级"] == "三级甲等"]

print("湖南省三甲医院数量为：", df_44_san_hospital.shape[0])


df_44_hospitals_guoying = df_44[df_44["经营方式"] == "国营"]

df_44_hospitals_guoying_san = df_44[df_44["经营方式"] != "国营"]

print("湖南省国盈三甲医院数量为：", df_44_hospitals_guoying_san.shape[0])


print("湖南省非国盈三甲医院数量为：", df_44_hospitals_guoying.shape[0])



df_45 = pd.read_excel(r'E:\daping\daping\hospital_sum\吉林省医院数据汇总.xls')




df_45_hospitals = df_45["医院等级"].value_counts()


df_45_san_hospital = df_45[df_45["医院等级"] == "三级甲等"]

print("吉林省三甲医院数量为：", df_45_san_hospital.shape[0])


df_45_hospitals_guoying = df_45[df_45["经营方式"] == "国营"]


df_45_hospitals_guoying_san = df_45[df_45["经营方式"] != "国营"]

print("吉林省国盈三甲医院数量为：", df_45_hospitals_guoying_san.shape[0])

print("吉林省非国盈三甲医院数量为：", df_45_hospitals_guoying.shape[0])





df_46 = pd.read_excel(r'E:\daping\daping\hospital_sum\江苏省医院数据汇总.xls')


df_46_hospitals = df_46["医院等级"].value_counts()

df_46_san_hospital = df_46[df_46["医院等级"] == "三级甲等"]

print("江苏省三甲医院数量为：", df_46_san_hospital.shape[0])

df_46_hospitals_guoying = df_46[df_46["经营方式"] == "国营"]

df_46_hospitals_guoying_san = df_46[df_46["经营方式"] != "国营"]

print("江苏省国盈三甲医院数量为：", df_46_hospitals_guoying_san.shape[0])

print("江苏省非国盈三甲医院数量为：", df_46_hospitals_guoying.shape[0])


df_47 = pd.read_excel(r'E:\daping\daping\hospital_sum\江西省医院数据汇总.xls')


df_47_hospitals = df_47["医院等级"].value_counts()

df_47_san_hospital = df_47[df_47["医院等级"] == "三级甲等"]

print("江西省三甲医院数量为：", df_47_san_hospital.shape[0])

df_47_hospitals_guoying = df_47[df_47["经营方式"] == "国营"]

df_47_hospitals_guoying_san = df_47[df_47["经营方式"] != "国营"]

print("江西省国盈三甲医院数量为：", df_47_hospitals_guoying_san.shape[0])

print("江西省非国盈三甲医院数量为：", df_47_hospitals_guoying.shape[0])


df_48 = pd.read_excel(r'E:\daping\daping\hospital_sum\辽宁省医院数据汇总.xls')


df_48_hospitals = df_48["医院等级"].value_counts()

df_48_san_hospital = df_48[df_48["医院等级"] == "三级甲等"]

print("辽宁省三甲医院数量为：", df_48_san_hospital.shape[0])

df_48_hospitals_guoying = df_48[df_48["经营方式"] == "国营"]

df_48_hospitals_guoying_san = df_48[df_48["经营方式"] != "国营"]

print("辽宁省国盈三甲医院数量为：", df_48_hospitals_guoying_san.shape[0])

print("辽宁省非国盈三甲医院数量为：", df_48_hospitals_guoying.shape[0])



print("_______________________________________________________________________________________________")

# data_hospital = pd.DataFrame([df_1_hospitals, df_2_hospitals, df_3_hospitals, df_4_hospitals, df_5_hospitals, df_6_hospitals, df_7_hospitals, df_8_hospitals, df_9_hospitals, df_10_hospitals, df_11_hospitals, df_12_hospitals, df_13_hospitals, df_14_hospitals, df_15_hospitals, df_16_hospitals, df_17_hospitals, df_18_hospitals, df_19_hospitals, df_20_hospitals, df_21_hospitals, df_22_hospitals, df_23_hospitals, df_24_hospitals, df_25_hospitals, df_26_hospitals, df_27_hospitals, df_28_hospitals, df_29_hospitals, df_30_hospitals, df_31_hospitals, df_32_hospitals, df_33_hospitals, df_34_hospitals, df_35_hospitals, df_36_hospitals, df_37_hospitals, df_38_hospitals, df_39_hospitals, df_40_hospitals, df_41_hospitals, df_42_hospitals, df_43_hospitals, df_44_hospitals, df_45_hospitals, df_46_hospitals, df_47_hospitals, df_48_hospitals])

# print(data_hospital)    

# 把上面统计的各个省份三甲医院数量拼接为一个列表
df_sum = []
df_sum = []
df_sum.extend([
    df_1_san_hospital.shape[0],
    df_2_san_hospital.shape[0],
    df_3_san_hospital.shape[0],
    df_4_san_hospital.shape[0],
    df_5_san_hospital.shape[0],
    df_6_san_hospital.shape[0],
    df_7_san_hospital.shape[0],
    df_8_san_hospital.shape[0],
    df_9_san_hospital.shape[0],
    df_10_san_hospital.shape[0],
    df_11_san_hospital.shape[0],
    df_12_san_hospital.shape[0],
    df_13_san_hospital.shape[0],
    df_14_san_hospital.shape[0],
    df_15_san_hospital.shape[0],
    df_16_san_hospital.shape[0],
    df_17_san_hospital.shape[0],
    df_18_san_hospital.shape[0],
    df_19_san_hospital.shape[0],
    df_20_san_hospital.shape[0],
    df_21_san_hospital.shape[0],
    df_22_san_hospital.shape[0],
    df_23_san_hospital.shape[0],
    df_24_san_hospital.shape[0],
    df_25_san_hospital.shape[0],
    df_26_san_hospital.shape[0],
    df_27_san_hospital.shape[0],
    df_28_san_hospital.shape[0],
    df_29_san_hospital.shape[0],
    df_30_san_hospital.shape[0],
    df_31_san_hospital.shape[0],
    df_32_san_hospital.shape[0],
    df_33_san_hospital.shape[0],
    df_34_san_hospital.shape[0],
    df_35_san_hospital.shape[0],
    df_36_san_hospital.shape[0],
    df_37_san_hospital.shape[0],
    df_38_san_hospital.shape[0],
    df_39_san_hospital.shape[0],
    df_40_san_hospital.shape[0],
    df_41_san_hospital.shape[0],
    df_42_san_hospital.shape[0],
    df_43_san_hospital.shape[0],
    df_44_san_hospital.shape[0],
    df_45_san_hospital.shape[0],
    df_46_san_hospital.shape[0],
    df_47_san_hospital.shape[0],
    df_48_san_hospital.shape[0]
])
print("_______________________________________________________________________________________________")
print(df_sum)

# 把上面统计的各个省份国盈医院拼接为一个列表
df_sum_guoying = []

df_sum_guoying.extend([
    df_1_hospitals_guoying_san.shape[0],
    df_2_hospitals_guoying_san.shape[0],
    df_3_hospitals_guoying_san.shape[0],
    df_4_hospitals_guoying_san.shape[0],
    df_5_hospitals_guoying_san.shape[0],
    df_6_hospitals_guoying_san.shape[0],
    df_7_hospitals_guoying_san.shape[0],
    df_8_hospitals_guoying_san.shape[0],
    df_9_hospitals_guoying_san.shape[0],
    df_10_hospitals_guoying_san.shape[0],
    df_11_hospitals_guoying_san.shape[0],
    df_12_hospitals_guoying_san.shape[0],
    df_13_hospitals_guoying_san.shape[0],
    df_14_hospitals_guoying_san.shape[0],
    df_15_hospitals_guoying_san.shape[0],
    df_16_hospitals_guoying_san.shape[0],
    df_17_hospitals_guoying_san.shape[0],
    df_18_hospitals_guoying_san.shape[0],
    df_19_hospitals_guoying_san.shape[0],
    df_20_hospitals_guoying_san.shape[0],
    df_21_hospitals_guoying_san.shape[0],
    df_22_hospitals_guoying_san.shape[0],
    df_23_hospitals_guoying_san.shape[0],
    df_24_hospitals_guoying_san.shape[0],
    df_25_hospitals_guoying_san.shape[0],
    df_26_hospitals_guoying_san.shape[0],
    df_27_hospitals_guoying_san.shape[0],
    df_28_hospitals_guoying_san.shape[0],
    df_29_hospitals_guoying_san.shape[0],
    df_30_hospitals_guoying_san.shape[0],
    df_31_hospitals_guoying_san.shape[0],
    df_32_hospitals_guoying_san.shape[0],
    df_33_hospitals_guoying_san.shape[0],

    df_34_hospitals_guoying_san.shape[0],
    df_35_hospitals_guoying_san.shape[0],
    df_36_hospitals_guoying_san.shape[0],

    df_37_hospitals_guoying_san.shape[0],
    df_38_hospitals_guoying_san.shape[0],
    df_39_hospitals_guoying_san.shape[0],
    df_40_hospitals_guoying_san.shape[0],
    df_41_hospitals_guoying_san.shape[0],
    df_42_hospitals_guoying_san.shape[0],
    df_43_hospitals_guoying_san.shape[0],
    df_44_hospitals_guoying_san.shape[0],
    df_45_hospitals_guoying_san.shape[0],
    df_46_hospitals_guoying_san.shape[0],
    df_47_hospitals_guoying_san.shape[0],
    df_48_hospitals_guoying_san.shape[0]
])
print("_______________________________________________________________________________________________")
print(df_sum_guoying)

# 把上面统计的各个省份非国盈医院拼接为一个列表

df_sum_fei_guoying = []

df_sum_fei_guoying.extend([
    df_1_hospitals_guoying.shape[0],
    df_2_hospitals_guoying.shape[0],
    df_3_hospitals_guoying.shape[0],
    df_4_hospitals_guoying.shape[0],
    df_5_hospitals_guoying.shape[0],
    df_6_hospitals_guoying.shape[0],
    df_7_hospitals_guoying.shape[0],
    df_8_hospitals_guoying.shape[0],
    df_9_hospitals_guoying.shape[0],
    df_10_hospitals_guoying.shape[0],
    df_11_hospitals_guoying.shape[0],
    df_12_hospitals_guoying.shape[0],
    df_13_hospitals_guoying.shape[0],
    df_14_hospitals_guoying.shape[0],
    df_15_hospitals_guoying.shape[0],
    df_16_hospitals_guoying.shape[0],
    df_17_hospitals_guoying.shape[0],
    df_18_hospitals_guoying.shape[0],
    df_19_hospitals_guoying.shape[0],
    df_20_hospitals_guoying.shape[0],
    df_21_hospitals_guoying.shape[0],
    df_22_hospitals_guoying.shape[0],
    df_23_hospitals_guoying.shape[0],
    df_24_hospitals_guoying.shape[0],
    df_25_hospitals_guoying.shape[0],
    df_26_hospitals_guoying.shape[0],
    df_27_hospitals_guoying.shape[0],
    df_28_hospitals_guoying.shape[0],
    df_29_hospitals_guoying.shape[0],
    df_30_hospitals_guoying.shape[0],
    df_31_hospitals_guoying.shape[0],
    df_32_hospitals_guoying.shape[0],
    df_33_hospitals_guoying.shape[0],
    df_34_hospitals_guoying.shape[0],
    df_35_hospitals_guoying.shape[0],
    df_36_hospitals_guoying.shape[0],
    df_37_hospitals_guoying.shape[0],
    df_38_hospitals_guoying.shape[0],
    df_39_hospitals_guoying.shape[0],
    df_40_hospitals_guoying.shape[0],
    df_41_hospitals_guoying.shape[0],
    df_42_hospitals_guoying.shape[0],
    df_43_hospitals_guoying.shape[0],
    df_44_hospitals_guoying.shape[0],
    df_45_hospitals_guoying.shape[0],
    df_46_hospitals_guoying.shape[0],
    df_47_hospitals_guoying.shape[0],
    df_48_hospitals_guoying.shape[0]
])
print("_______________________________________________________________________________________________")
print(df_sum_fei_guoying)

# 拼接数据

df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22, df_23, df_24, df_25, df_26, df_27, df_28, df_29, df_30, df_31, df_32, df_33, df_34, df_35, df_36, df_37, df_38, df_39, df_40, df_41, df_42, df_43, df_44, df_45, df_46, df_47, df_48], axis=0, ignore_index=True)

df.to_csv(r'E:\daping\daping\hospital_sum\hospital_sum.csv', index=False, encoding='utf-8-sig')
